# %%
import speech_recognition as sr
import pyttsx3
import datetime
import webbrowser
import openai
import subprocess
import os

openai.api_key = "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"

def speak(text):
    engine = pyttsx3.init()
    voices = engine.getProperty('voices')
    engine.setProperty('voice', voices[1].id) # change to voice index 1 for female voice
    engine.say(text)
    engine.runAndWait()

def listen():
    recognizer = sr.Recognizer()
    microphone = sr.Microphone()
    
    with microphone as source:
        recognizer.adjust_for_ambient_noise(source)
        print("Say something:")
        audio = recognizer.listen(source)

    try:
        text = recognizer.recognize_google(audio, language='en-US')
        print("You said: {}".format(text))
    except sr.UnknownValueError:
        print("Sorry, I could not understand what you said")
        text = None
    except sr.RequestError as e:
        print("Error accessing the Google Speech Recognition service: {0}".format(e))
        text = None
        
    return text
import os

...

def main():
    while True:
        text = listen()
        if text is None:
             continue
        text = text.lower()
        if "hey friday" in text:
            speak("Hello! How can I help you today?")
        elif "what time is it" in text:
            now = datetime.datetime.now()
            speak("The current time is {}:{}:{}".format(now.hour, now.minute, now.second))
        elif "search" in text:
            search_term = text.replace("search", "").strip()
            response = openai.Completion.create(
                engine="text-davinci-002",
                prompt="search " + search_term,
                max_tokens=1024,
                n=1,
                stop=None,
                temperature=0.5,
            ).choices[0].text
            print(response)
            speak("According to my search, " + response)
            print("|||||||||------------------------------------------------------------------------------------------|||||")
            break
        elif "play video on youtube" in text:
            search_term = text.replace("play video on youtube", "").strip()
            url = "https://www.youtube.com/results?search_query=" + search_term
            webbrowser.open(url)
            speak("Playing the video on youtube for {}".format(search_term))
        elif "play song on spotify" in text:
            search_term = text.replace("play song on spotify", "").strip()
            url = "https://open.spotify.com/search/" + search_term
            webbrowser.open(url)
            speak("Playing the song on spotify for {}".format(search_term))
        elif "find" in text:
            search_term = text.replace("find", "").strip()
            url = "https://google.com/search?q=" + search_term
            webbrowser.open(url)
            speak("Here's your search result for {}".format(search_term))
            break
        elif "stop" in text:
            speak("Time period of me is over, thank you sir.")
            break
        elif "open notepad" in text:
            subprocess.call(["notepad.exe"])
            speak("Opening Notepad.")
        elif "open spotify" in text:
            subprocess.call(["spotify.exe"])
            speak("Opening Spotify.")
        elif "open asphalt" in text:
            subprocess.call(["asphalt 9 legends.exe"])
            speak("Opening Asphalt 9 Legends.")
        elif "open calculator" in text:
            subprocess.call(["calc.exe"])
            speak("Opening Calculator.")
        elif "open paint" in text:
            subprocess.call(["mspaint.exe"])
            speak("Opening Paint.")
        elif "shutdown" in text:
            os.system("shutdown /s /t 1")
            speak("Shutting down the PC.")
            break
        elif "restart" in text:
            subprocess.call(["shutdown", "/r", "/t", "1"])
            speak("restarting your device.i will be back once the device gets booted")
            break
        elif "lock" in text:
            os.system("rundll32.exe user32.dll,LockWorkStation")
            speak("Locking your device.")
            break
        elif "sleep" in text:
            subprocess.call(["rundll32.exe", "powrprof.dll,SetSuspendState"])
            speak("Putting the PC to sleep.")
            break

        
        else:
            response = openai.Completion.create(
                engine="text-davinci-002",
                prompt=text,
                max_tokens=1024,
                n=1,
                stop=None,
                temperature=0.5,
            )
if __name__ == "__main__":
    main()
# Out:
# Say something:
# You said: sleep sleep
